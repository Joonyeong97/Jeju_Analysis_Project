# %%
from matplotlib import font_manager, rc
font_name=font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family =font_name)


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

insolation_6 =pd.read_csv('C:/Users/ICT01_09/Documents/project_madarin/6ins.csv', encoding='CP949')

# weather_jeju.index=weather_jeju['일시']
# weather_jeju.drop(labels=['일시'], axis=1)

insolation_6.index = insolation_6['Jun']
insolation_6 = insolation_6.iloc[5:, :]
insolation_6.drop(labels=['Jun'], axis = 1, inplace = True)
insolation_6

# %%
insolation_6.plot()

# 1980, 1981 6월 일사량 - 이상치

# %%
insolation_7 = pd.read_csv('C:/Users/ICT01_09/Documents/project_madarin/7ins.csv', encoding='CP949')
insolation_7.index = insolation_7['Jul']
insolation_7 = insolation_7.iloc[5:, :]
insolation_7.drop(labels=['Jul'], axis = 1, inplace = True)
insolation_7.plot()
insolation_7
# Out:
#           insolation
# Jul
#  1985-07      626.32
#  1986-07      455.71
#  1987-07      427.15
#  1988-07      614.36
#  1989-07      556.34
#  1990-07      574.86
#  1991-07      470.98
#  1992-07      522.83
#  1993-07      409.07
#  1994-07      682.25
#  1995-07      530.51
#  1996-07      468.03
#  1997-07      534.55
#  1998-07      601.67
#  1999-07      432.37
#  2000-07      614.81
#  2001-07      635.99
#  2002-07      503.99
#  2003-07      399.71
#  2004-07      709.95
#  2005-07      535.80
#  2006-07      541.32
#  2007-07      529.53
#  2008-07      659.78
#  2009-07      574.58
#  2010-07      574.45
#  2011-07      681.13
#  2012-07      580.38
#  2013-07      658.01
#  2014-07      468.17
#  2015-07      593.93
#  2016-07      610.55
#  2017-07      617.20
#  2018-07      632.09

# %%
insolation_8 = pd.read_csv('C:/Users/ICT01_09/Documents/project_madarin/8ins.csv', encoding='CP949')
insolation_8.index = insolation_8['Aug']
insolation_8 = insolation_8.iloc[5:, :]
insolation_8.drop(labels=['Aug'], axis = 1, inplace = True)
insolation_8.plot()
insolation_8
# Out:
#           insolation
# Aug
#  1985-08      557.11
#  1986-08      572.22
#  1987-08      501.60
#  1988-08      588.09
#  1989-08      524.67
#  1990-08      660.71
#  1991-08      523.38
#  1992-08      426.05
#  1993-08      362.44
#  1994-08      659.15
#  1995-08      601.83
#  1996-08      479.78
#  1997-08      451.56
#  1998-08      627.19
#  1999-08      424.40
#  2000-08      632.70
#  2001-08      603.10
#  2002-08      486.37
#  2003-08      515.46
#  2004-08      589.97
#  2005-08      559.19
#  2006-08      596.54
#  2007-08      661.13
#  2008-08      591.40
#  2009-08      608.99
#  2010-08      613.50
#  2011-08      520.98
#  2012-08      633.44
#  2013-08      662.33
#  2014-08      402.01
#  2015-08      530.07
#  2016-08      631.34
#  2017-08      619.22
#  2018-08      613.70

# %%
insolation_10 = pd.read_csv('C:/Users/ICT01_09/Documents/project_madarin/10ins.csv', encoding='CP949')
insolation_10 = insolation_10.iloc[5:, :]
#insolation_10.drop(labels=['Sep'], axis = 1, inplace = True)
insolation_10.plot()
insolation_10
# Out:
#          Sep  insolation
# 5    1985-10      325.46
# 6    1986-10      402.59
# 7    1987-10      330.41
# 8    1988-10      472.44
# 9    1989-10      500.44
# 10   1990-10      453.59
# 11   1991-10      464.36
# 12   1992-10      347.99
# 13   1993-10      353.43
# 14   1994-10      466.03
# 15   1995-10      403.88
# 16   1996-10      358.22
# 17   1997-10      419.52
# 18   1998-10      388.16
# 19   1999-10      371.48
# 20   2000-10      396.97
# 21   2001-10      440.16
# 22   2002-10      401.06
# 23   2003-10      443.30
# 24   2004-10      452.88
# 25   2005-10      378.68
# 26   2006-10      451.23
# 27   2007-10      462.07
# 28   2008-10      434.31
# 29   2009-10      499.10
# 30   2010-10      416.35
# 31   2011-10      471.52
# 32   2012-10      503.96
# 33   2013-10      476.96
# 34   2014-10      396.31
# 35   2015-10      455.29
# 36   2016-10      276.31
# 37   2017-10      316.02
# 38   2018-10      390.77

# %%
insolation_11 = pd.read_csv('C:/Users/ICT01_09/Documents/project_madarin/11ins.csv', encoding='CP949')
insolation_11.index = insolation_11['Nov']
insolation_11 = insolation_11.iloc[5:, :]
insolation_11.drop(labels=['Nov'], axis = 1, inplace = True)
insolation_11.plot()
insolation_11
# Out:
#           insolation
# Nov
#  1985-11      224.56
#  1986-11      242.01
#  1987-11      244.29
#  1988-11      325.86
#  1989-11      289.32
#  1990-11      233.42
#  1991-11      302.80
#  1992-11      237.44
#  1993-11      183.36
#  1994-11      347.29
#  1995-11      311.47
#  1996-11      220.05
#  1997-11      211.38
#  1998-11      334.98
#  1999-11      251.17
#  2000-11      316.00
#  2001-11      322.89
#  2002-11      271.25
#  2003-11      218.55
#  2004-11      295.33
#  2005-11      277.85
#  2006-11      231.51
#  2007-11      325.24
#  2008-11      267.05
#  2009-11      251.22
#  2010-11      329.25
#  2011-11      285.15
#  2012-11      299.57
#  2013-11      285.47
#  2014-11      242.51
#  2015-11      175.93
#  2016-11      247.40
#  2017-11      288.30
#  2018-11      294.87

# %%
rain_10 = pd.read_csv('C:/Users/ICT01_09/Documents/project_madarin/rain_10.csv', encoding='CP949')
rain_10 = rain_10.iloc[5:, :]
rain_10.drop(labels=['평균상대습도'], axis = 1, inplace = True)

rain_10.plot()
rain_10
# Out:
#         Sep.  강수량mm
# 5    1985-10  421.4
# 6    1986-10   67.6
# 7    1987-10   18.3
# 8    1988-10   15.8
# 9    1989-10  115.1
# 10   1990-10  116.2
# 11   1991-10   22.9
# 12   1992-10    7.5
# 13   1993-10   83.2
# 14   1994-10  271.1
# 15   1995-10  103.1
# 16   1996-10  194.5
# 17   1997-10   14.0
# 18   1998-10   70.1
# 19   1999-10   80.0
# 20   2000-10  213.5
# 21   2001-10  176.0
# 22   2002-10  182.8
# 23   2003-10   51.5
# 24   2004-10   46.0
# 25   2005-10   64.5
# 26   2006-10   68.0
# 27   2007-10  183.0
# 28   2008-10   91.0
# 29   2009-10   82.1
# 30   2010-10  125.0
# 31   2011-10   71.0
# 32   2012-10   47.0
# 33   2013-10  116.6
# 34   2014-10  203.9
# 35   2015-10   61.0
# 36   2016-10  433.6
# 37   2017-10  389.1
# 38   2018-10  347.0

# %%
sep = pd.concat([insolation_10, rain_10], ignore_index=False, axis = 1)
#sep = pd.merge(insolation_10, rain_10, left_on = 'insolation_10', right_on = 'rain_10', left_index=True, right_index=True)
sep.drop(labels=['Sep.'], axis = 1, inplace = True)
sep
sep.plot()

# %%
pre_10 = pd.read_csv ('C:/Users/ICT01_09/Documents/project_madarin/rain_10.csv', encoding='CP949')
pre_10.index = pre_10['Sep.']
pre_10.drop(labels = ['Sep.'], axis = 1, inplace = True)
pre_10.plot()
pre_10
# Out:
#           강수량mm  평균상대습도
# Sep.
#  1980-10  162.6      77
#  1981-10  169.2      74
#  1982-10   67.5      78
#  1983-10   77.5      76
#  1984-10   28.4      69
#  1985-10  421.4      76
#  1986-10   67.6      77
#  1987-10   18.3      74
#  1988-10   15.8      73
#  1989-10  115.1      76
#  1990-10  116.2      75
#  1991-10   22.9      72
#  1992-10    7.5      75
#  1993-10   83.2      70
#  1994-10  271.1      71
#  1995-10  103.1      72
#  1996-10  194.5      72
#  1997-10   14.0      69
#  1998-10   70.1      79
#  1999-10   80.0      73
#  2000-10  213.5      74
#  2001-10  176.0      69
#  2002-10  182.8      72
#  2003-10   51.5      66
#  2004-10   46.0      67
#  2005-10   64.5      71
#  2006-10   68.0      74
#  2007-10  183.0      71
#  2008-10   91.0      68
#  2009-10   82.1      60
#  2010-10  125.0      74
#  2011-10   71.0      68
#  2012-10   47.0      74
#  2013-10  116.6      74
#  2014-10  203.9      75
#  2015-10   61.0      71
#  2016-10  433.6      81
# ...

# %%
man = pd.read_csv('C:/Users/ICT01_09/Documents/project_madarin/2018 statisitic.csv', encoding='UTF-8')
man['생산량톤'] = man['생산량 천t'] * 1000
man['단수 kg/10a 기준'] = man['생산량톤']/man['재배면적'] *100
man

man = merge.man
# Out:
#       연도   재배면적  생산량 천t    증감률    생산량톤  단수 kg/10a 기준
# 0   1985  16000     394  0.000  394000   2462.500000
# 1   1986  16000     331 -0.155  331000   2068.750000
# 2   1987  17000     464  0.394  464000   2729.411765
# 3   1988  18000     412 -0.111  412000   2288.888889
# 4   1989  18727     746  0.809  746000   3983.553159
# 5   1990  19300     493 -0.340  493000   2554.404145
# 6   1991  19605     556  0.129  556000   2836.011222
# 7   1992  21479     718  0.292  718000   3342.799944
# 8   1993  21727     619 -0.139  619000   2848.989736
# 9   1994  21500     548 -0.113  548000   2548.837209
# 10  1995  23662     615  0.120  615000   2599.104049
# 11  1996  25820     480 -0.219  480000   1859.024012
# 12  1997  25860     693  1.444  693000   2679.814385
# 13  1998  25870     544 -0.215  544000   2102.821801
# 14  1999  25781     639  0.175  639000   2478.569489
# 15  2000  26813     563 -0.119  563000   2099.727744
# 16  2001  26650     645  0.146  645000   2420.262664
# ...
