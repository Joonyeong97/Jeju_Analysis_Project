# %%
from matplotlib import font_manager, rc
font_name=font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family =font_name)


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

mandarin_cultivated=pd.read_csv('D:/1-project/ppt/지영 _감귤 생산량/mandarin_cultivated.csv', encoding='CP949')
mandarin_cultivated.info() # 문자열 바꾸기 귀찮아서 ㅋㅋㅋㅋㅋ

mandarin_cultivated.columns=["연도", "성과수면적"]
mandarin_cultivated
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
# index    27 non-null int64
# 1        27 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 560.0 bytes
#       연도       성과수면적
# 0   1993  17808.0000
# 1   1994  17944.0000
# 2   1995  19460.0000
# 3   1996  21838.0000
# 4   1997  22366.0000
# 5   1998  22808.0000
# 6   1999  23311.0000
# 7   2000  23705.0000
# 8   2001  23565.0000
# 9   2002  23314.0000
# 10  2003  21635.0000
# 11  2004  19214.0000
# 12  2005  18642.0000
# 13  2006  18289.0000
# 14  2007  18223.0000
# 15  2008  17889.0000
# 16  2009  17901.0000
# 17  2010  17573.0000
# 18  2011  17378.0000
# 19  2012  17146.0000
# 20  2013  16993.0000
# 21  2014  16439.0000
# 22  2015  16112.0000
# 23  2016  17049.0000
# 24  2017  16630.6223
# 25  2018  16029.7769
# 26  2019  15386.0820

# %%
mandarin =pd.read_csv("D:/1-project/ppt/지영 _감귤 생산량/2018 statisitic.csv", 
                        encoding='UTF-8')
mandarin["생산량 톤"]=mandarin.iloc[:,2]*1000
mandarin["단수 kg/10a 기준"]=mandarin["생산량 톤"]/mandarin["재배면적"] *100
result=mandarin.copy()
result=result.iloc[8:,]
result=result.reset_index()
result.drop(labels="index", axis=1, inplace=True)
result
# Out:
#       연도   재배면적  생산량 천t    증감률   생산량 톤  단수 kg/10a 기준
# 0   1993  21727     619 -0.139  619000   2848.989736
# 1   1994  21500     548 -0.113  548000   2548.837209
# 2   1995  23662     615  0.120  615000   2599.104049
# 3   1996  25820     480 -0.219  480000   1859.024012
# 4   1997  25860     693  1.444  693000   2679.814385
# 5   1998  25870     544 -0.215  544000   2102.821801
# 6   1999  25781     639  0.175  639000   2478.569489
# 7   2000  26813     563 -0.119  563000   2099.727744
# 8   2001  26650     645  0.146  645000   2420.262664
# 9   2002  26234     643 -0.003  643000   2451.017763
# 10  2003  24560     632 -0.017  632000   2573.289902
# 11  2004  22048     584 -0.076  584000   2648.766328
# 12  2005  21430     638  0.092  638000   2977.134858
# 13  2006  21382     620 -0.028  620000   2899.635207
# 14  2007  21463     778  0.255  778000   3624.842753
# 15  2008  21201     636 -0.183  636000   2999.858497
# 16  2009  21354     727  0.143  727000   3404.514377
# ...

# %%
dataset=pd.merge(result,mandarin_cultivated)
dataset["성과수비율"]=dataset.iloc[:,6]/dataset.iloc[:,1]
dataset
# Out:
#       연도   재배면적  생산량 천t    증감률   생산량 톤  단수 kg/10a 기준       성과수면적     성과수비율
# 0   1993  21727     619 -0.139  619000   2848.989736  17808.0000  0.819625
# 1   1994  21500     548 -0.113  548000   2548.837209  17944.0000  0.834605
# 2   1995  23662     615  0.120  615000   2599.104049  19460.0000  0.822416
# 3   1996  25820     480 -0.219  480000   1859.024012  21838.0000  0.845778
# 4   1997  25860     693  1.444  693000   2679.814385  22366.0000  0.864888
# 5   1998  25870     544 -0.215  544000   2102.821801  22808.0000  0.881639
# 6   1999  25781     639  0.175  639000   2478.569489  23311.0000  0.904193
# 7   2000  26813     563 -0.119  563000   2099.727744  23705.0000  0.884086
# 8   2001  26650     645  0.146  645000   2420.262664  23565.0000  0.884240
# 9   2002  26234     643 -0.003  643000   2451.017763  23314.0000  0.888694
# 10  2003  24560     632 -0.017  632000   2573.289902  21635.0000  0.880904
# ...

# %%
dataset.columns=['year','cultivatedArea','productionTT','productionRate','productionT','dansu','agingCultivatedArea','agingRate']
#dataset
mandarin.dataset=dataset[["year",'productionT']]#, "cultivatedArea",'agingCultivatedArea',"agingRate"
mandarin.dataset
# Out:
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   This is separate from the ipykernel package so we can avoid doing imports until
#     year  productionT
# 0   1993       619000
# 1   1994       548000
# 2   1995       615000
# 3   1996       480000
# 4   1997       693000
# 5   1998       544000
# 6   1999       639000
# 7   2000       563000
# 8   2001       645000
# 9   2002       643000
# 10  2003       632000
# 11  2004       584000
# 12  2005       638000
# 13  2006       620000
# 14  2007       778000
# 15  2008       636000
# 16  2009       727000
# 17  2010       615000
# 18  2011       645000
# 19  2012       654000
# 20  2013       655000
# 21  2014       688000
# 22  2015       640000
# 23  2016       610000
# 24  2017       597000
# 25  2018       621000

# %%
weatherBloom =pd.read_csv("D:/1-project/j4,5.csv", 
                        encoding='CP949')

weatherBloom.columns=['Bloom', 'TempOfBloom', 'PrecipitationOfBloom', 'InsolationOfBloom', 
                     'HumidityOfBloom', 'WindspeedOfBloom','PHUOfBloom']
weatherBloom.drop(labels="Bloom", axis=1, inplace=True)
weatherBloom.drop(labels="TempOfBloom",axis=1, inplace=True)

# %%
weatherHarvest =pd.read_csv("D:/1-project/j7,8,9.csv", 
                        encoding='CP949')

weatherHarvest.columns=['Harvest', 'TempOfHarvest', 'PrecipitationOfHarvest', 'InsolationOfHarvest', 
                     'HumidityOfHarvest', 'WindspeedOfHarvest','PHUOfHarvest']

weatherHarvest.drop(labels="Harvest", axis=1, inplace=True)

weatherHarvest.drop(labels="TempOfHarvest",axis=1, inplace=True)

# %%
weather=pd.merge(weatherBloom,weatherHarvest, left_index=True, right_index=True)
print(weather)
# Out:
#     PrecipitationOfBloom  InsolationOfBloom  HumidityOfBloom  \
# 0                 158.30            489.345             78.5
# 1                 224.40            473.190             83.5
# 2                 256.30            533.630             76.0
# 3                 152.70            532.375             73.0
# 4                 200.85            508.275             74.0
# 5                 193.85            456.845             88.0
# 6                 189.80            586.580             80.5
# 7                 111.35            622.505             75.0
# 8                 182.75            597.355             75.0
# 9                 189.50            488.165             79.0
# 10                308.50            504.225             79.5
# 11                339.15            521.545             77.5
# 12                136.60            637.320             73.0
# 13                268.15            512.640             78.0
# ...

# %%
mandarinDataset=pd.merge(mandarin.dataset, weather, left_index=True, right_index=True)
mandarinDataset.index=mandarinDataset['year']
mandarinDataset.drop(labels='year', axis=1, inplace=True)
mandarinDataset
# Out:
#       productionT  PrecipitationOfBloom  InsolationOfBloom  HumidityOfBloom  \
# year
# 1993       619000                158.30            489.345             78.5
# 1994       548000                224.40            473.190             83.5
# 1995       615000                256.30            533.630             76.0
# 1996       480000                152.70            532.375             73.0
# 1997       693000                200.85            508.275             74.0
# 1998       544000                193.85            456.845             88.0
# 1999       639000                189.80            586.580             80.5
# 2000       563000                111.35            622.505             75.0
# 2001       645000                182.75            597.355             75.0
# 2002       643000                189.50            488.165             79.0
# 2003       632000                308.50            504.225             79.5
# ...

# %%
mandarinDataset.describe()
# Out:
#          productionT  PrecipitationOfBloom  InsolationOfBloom  \
# count      26.000000             26.000000          26.000000
# mean   628038.461538            211.340385         564.935000
# std     58691.383197             74.530217          60.445129
# min    480000.000000            111.350000         456.845000
# 25%    611250.000000            148.162500         514.866250
# 50%    634000.000000            191.825000         568.065000
# 75%    645000.000000            256.100000         612.687500
# max    778000.000000            358.600000         665.700000
#
#        HumidityOfBloom  WindspeedOfBloom  PHUOfBloom  PrecipitationOfHarvest  \
# count        26.000000         26.000000   26.000000               26.000000
# mean         77.307692          6.123077   21.212346              324.669231
# std           4.606684          0.628368    1.432233              136.491748
# min          69.000000          4.950000   18.320000              110.466667
# ...

# %%
# 변수들끼리 상관관계를 분석해봅시다
y = mandarinDataset.iloc[:,1]
X = mandarinDataset.iloc[:,1:]


# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,15))
sns.heatmap(data=X.corr(), annot=True, fmt='.2f', linewidths=.5, cmap='hot_r')


# Temp2개, 수확기 일조량 제가해야함
# Out:
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 수확기의 일조량은 착색에 연관이 있으나, 다중공선성 70% 넘어서 제외 => 비상품군, 생산량에는 포함
mandarinDataset.drop(labels="InsolationOfHarvest", axis=1, inplace=True)

# %%
y=mandarinDataset.iloc[:,-1]
X=mandarinDataset.iloc[:,1:]

plt.figure(figsize=(15,15))
sns.heatmap(data=X.corr(), annot=True, fmt='.3f', linewidths=.5, cmap='hot_r')

# %%
from sklearn.feature_selection import RFE #recursive feature elimination 
from sklearn.svm import SVR # 이번엔 분류! SVRegression

estimator =SVR(kernel='linear') #선형회귀Regression 예측 

# 분산이 작은 데이터 == 가장 영향력 없는 변수 > noise 제거 noise elimination)
selector =RFE(estimator, 5, step=1) # step=1 :1번에 1개씩 제거해라
# 5개 변수에 대해서 스텝 1개씩. = 10개 변수중에서 5개만 남기겠다. 

# RFE(): ( 기존의 추정기를 받고 , 변수추출갯수(제거후), step 지정 )
selector = selector.fit(X, y)
selector.support_
# Out:
# array([ True, False,  True,  True,  True, False, False, False, False,
#         True])

# %%
selector.ranking_
# Out:
# array([1, 4, 1, 1, 1, 6, 5, 3, 2, 1])

# %%
selector.n_features_ # 잡음제거한 변수 5개 남김.
# Out:
# 5

# %%
selector.estimator_ # 변수를 제거한 추정기.
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
from sklearn.metrics import pairwise_distances # 유클리디안 거리 = 각 점들간의 상호거리 =상관계수??
D= pairwise_distances(X)
print(D.shape)
fig=plt.figure(figsize=(20,10))
plt.imshow(D, zorder=10, cmap='viridis_r', interpolation='nearest')
plt.colorbar
# Out:
# (26, 26)
# <function matplotlib.pyplot.colorbar(mappable=None, cax=None, ax=None, **kw)>

# %% [markdown]
# # PCA 모델 입력 전단계 = 특징추출하기 = noise 제거

# %%
mandarinDataset
# Out:
#       productionT  PrecipitationOfBloom  InsolationOfBloom  HumidityOfBloom  \
# year
# 1993       619000                158.30            489.345             78.5
# 1994       548000                224.40            473.190             83.5
# 1995       615000                256.30            533.630             76.0
# 1996       480000                152.70            532.375             73.0
# 1997       693000                200.85            508.275             74.0
# 1998       544000                193.85            456.845             88.0
# 1999       639000                189.80            586.580             80.5
# 2000       563000                111.35            622.505             75.0
# 2001       645000                182.75            597.355             75.0
# 2002       643000                189.50            488.165             79.0
# 2003       632000                308.50            504.225             79.5
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X)
print(pca.explained_variance_ratio_)

print(pca.explained_variance_) # 분산이 큰것이 주성분~~!
print(pca.noise_variance_) # Noise
# Out:
# [0.67795012 0.22289834]
# [18898.41480813  6213.47383211]
# 394.84715991899344

# %%
# 정규화 4가지 버젼 다 해보쟝

y = mandarinDataset.iloc[:,0]
X = mandarinDataset.iloc[:,1:]

from sklearn.preprocessing import scale, robust_scale, minmax_scale, maxabs_scale, StandardScaler
scale_X = scale(X)
robust_X = robust_scale(X)
minmax_X = minmax_scale(X)
maxabs_X = maxabs_scale(X)
scaler = StandardScaler()
stdScale_X = scaler.fit(X)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(minmax_X, y, random_state=0)


# 최소자승법을 해봅시다! (OLS)
import statsmodels.api as sm
result = sm.OLS(y_train, X_train).fit()
result.summary()
# Out:
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\scipy\stats\stats.py:1450: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:            productionT   R-squared (uncentered):                   0.985
# Model:                            OLS   Adj. R-squared (uncentered):              0.972
# Method:                 Least Squares   F-statistic:                              74.79
# Date:                Tue, 21 Jan 2020   Prob (F-statistic):                    5.51e-08
# Time:                        17:10:43   Log-Likelihood:                         -240.50
# No. Observations:                  19   AIC:                                      499.0
# Df Residuals:                      10   BIC:                                      507.5
# Df Model:                           9
# Covariance Type:            nonrobust
# ...

# %%
from sklearn.linear_model import LinearRegression
lg = LinearRegression()
lg.fit(X_train, y_train)
lg.predict(X_test)
lg.score(X_test, y_test)
# Out:
# -1.4240826174398418

# %%
mandarinDataset
# Out:
#       productionT  PrecipitationOfBloom  InsolationOfBloom  HumidityOfBloom  \
# year
# 1993       619000                158.30            489.345             78.5
# 1994       548000                224.40            473.190             83.5
# 1995       615000                256.30            533.630             76.0
# 1996       480000                152.70            532.375             73.0
# 1997       693000                200.85            508.275             74.0
# 1998       544000                193.85            456.845             88.0
# 1999       639000                189.80            586.580             80.5
# 2000       563000                111.35            622.505             75.0
# 2001       645000                182.75            597.355             75.0
# 2002       643000                189.50            488.165             79.0
# 2003       632000                308.50            504.225             79.5
# ...

# %%
# 특징중요도

from sklearn.datasets import load_boston
from sklearn.ensemble import RandomForestRegressor

y = mandarinDataset.iloc[:,0]
X = mandarinDataset.iloc[:,1:]
names = mandarinDataset.iloc[:,1:]
rf = RandomForestRegressor()
rf.fit(X,y)
# Out:
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
# 변수 중요도 (내림차순)
print(sorted(zip(map(lambda x : round(x,2), rf.feature_importances_), names), reverse = True))
# Out:
# [(0.2, 'WindspeedOfHarvest'), (0.2, 'PrecipitationOfHarvest'), (0.18, 'PrecipitationOfBloom'), (0.13, 'PHUOfHarvest'), (0.12, 'PHUOfBloom'), (0.06, 'HumidityOfBloom'), (0.05, 'InsolationOfBloom'), (0.04, 'HumidityOfHarvest'), (0.01, 'WindspeedOfBloom')]

# %%
# 시각화
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize = (6,4))
ax.bar(range(0, len(rf.feature_importances_)), rf.feature_importances_)
ax.set_title('feature importance')
# Out:
# Text(0.5, 1.0, 'feature importance')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
mean_squared_error(y, rf.predict(X))
# Out:
# 673265769.2307693

# %%
r2_score(y, rf.predict(X))
# Out:
# 0.7967309843812597

# %%
mandarinDataset.head()

import xgboost as xgb
from sklearn.metrics import mean_squared_error

data_dmarix = xgb.DMatrix(data = X, label = y)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)
# Out:
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %%
#mandarinDataset.iloc[:,0]
mandarinDataset.iloc[:,1:]
# Out:
#       PrecipitationOfBloom  InsolationOfBloom  HumidityOfBloom  \
# year
# 1993                158.30            489.345             78.5
# 1994                224.40            473.190             83.5
# 1995                256.30            533.630             76.0
# 1996                152.70            532.375             73.0
# 1997                200.85            508.275             74.0
# 1998                193.85            456.845             88.0
# 1999                189.80            586.580             80.5
# 2000                111.35            622.505             75.0
# 2001                182.75            597.355             75.0
# 2002                189.50            488.165             79.0
# 2003                308.50            504.225             79.5
# 2004                339.15            521.545             77.5
# 2005                136.60            637.320             73.0
# 2006                268.15            512.640             78.0
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
svm = SVC(C=100)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

svm.fit(X_train, y_train)
print("테스트 세트 정확도 :{:.2f}".format(svm.score(X_test, y_test)))
# Out:
# 테스트 세트 정확도 :0.00
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
svm = SVC(C=100)


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

from sklearn.decomposition import PCA
pca = PCA(n_components = 5)
pca.fit(X_train_scaled)
X_t_train = pca.transform(X_train_scaled)
#X_t_test = pca.transform(X_test_scaled)
svm.fit(X_t_train, y_train)

print("SVM 테스트 정확도 :{:.2f}".format(svm.score(X_t_train,y_train)))
# Out:
# SVM 테스트 정확도 :1.00
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(X)

SVC2 = SVC(degree=2,C=1).fit(scaled_data,y)

print('정확도:%.2f'%(SVC2.score(scaled_data,y)*100),"%")
# Out:
# 정확도:15.38 %
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
X
# Out:
#       PrecipitationOfBloom  InsolationOfBloom  HumidityOfBloom  \
# year
# 1993                158.30            489.345             78.5
# 1994                224.40            473.190             83.5
# 1995                256.30            533.630             76.0
# 1996                152.70            532.375             73.0
# 1997                200.85            508.275             74.0
# 1998                193.85            456.845             88.0
# 1999                189.80            586.580             80.5
# 2000                111.35            622.505             75.0
# 2001                182.75            597.355             75.0
# 2002                189.50            488.165             79.0
# 2003                308.50            504.225             79.5
# 2004                339.15            521.545             77.5
# 2005                136.60            637.320             73.0
# 2006                268.15            512.640             78.0
# ...

# %%
# 앙상블
from sklearn.ensemble import VotingRegressor,VotingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor

log_clf = LogisticRegression()
rnd_clf = RandomForestRegressor()
svm_clf = SVC()


voting_clf = VotingClassifier(estimators=[('lr', log_clf),('rf',rnd_clf),('svc',svm_clf)], voting = 'hard')

voting_clf.fit(X_t_train,y_train)
# Out:
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
# ...

# %%
from sklearn.metrics import accuracy_score
for clf in (log_clf,rnd_clf,svm_clf,voting_clf):
    clf.fit(X_t_train,y_train)
    print(clf.__class__.__name__, accuracy_score(X_t_train,y_train))
# Out:
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-200-1c7867cd4fe3> in <module>
#       2 for clf in (log_clf,rnd_clf,svm_clf,voting_clf):
#       3     clf.fit(X_t_train,y_train)
# ----> 4     print(clf.__class__.__name__, accuracy_score(X_t_train,y_train))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(minmax_X , y, random_state=0)


# 최소자승법을 해봅시다!
import statsmodels.api as sm
result = sm.OLS(y_train, X_train).fit()
result.summary()


# R-squared => 설명력 : 회귀제곱합/ 총오차제곱합 0.001  =>0.885
# Adj. R-squared 모델을 통해 수정된 값을 쓴다 -0.054   minmax 정규분포로 =>0.878
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:            productionT   R-squared (uncentered):                   0.985
# Model:                            OLS   Adj. R-squared (uncentered):              0.972
# Method:                 Least Squares   F-statistic:                              74.79
# Date:                Tue, 21 Jan 2020   Prob (F-statistic):                    5.51e-08
# Time:                        16:02:53   Log-Likelihood:                         -240.50
# No. Observations:                  19   AIC:                                      499.0
# Df Residuals:                      10   BIC:                                      507.5
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# z점수
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import scale, robust_scale, minmax_scale , maxabs_scale
scaler = scale(X)

#scaled_data = scale.fit(x)

logreg= LogisticRegression(solver='lbfgs',max_iter=20).fit(scaler,y)

print("Logi.Regre Z점수 정확도:%.2f" %(logreg.score(scaler,y)*100),"%")
#
scaler = maxabs_scale(X)

#scaled_data = scale.fit(x)

logreg= LogisticRegression(solver='lbfgs',max_iter=20).fit(scaler,y)

print('Logi.Regre maxabs점수 정확도:%.2f'%(logreg.score(scaler,y)*100),"%")
#
scaler = minmax_scale(X)

#scaled_data = scale.fit(x)

logreg= LogisticRegression(solver='lbfgs',max_iter=20).fit(scaler,y)

print('Logi.Regre minmax점수 정확도:%.2f'%(logreg.score(scaler,y)*100),"%")
#
scaler = robust_scale(X)

#scaled_data = scale.fit(x)

logreg= LogisticRegression(solver='lbfgs',max_iter=20).fit(scaler,y)

print('Logi.Regre robust점수 정확도:%.2f'%(logreg.score(scaler,y)*100),"%")
# Out:
# Logi.Regre Z점수 정확도:100.00 %
# Logi.Regre maxabs점수 정확도:15.38 %
# Logi.Regre minmax점수 정확도:34.62 %
# Logi.Regre robust점수 정확도:96.15 %
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
# Random forest scale
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.preprocessing import scale, robust_scale, minmax_scale , maxabs_scale
scaler = scale(X)

RandomF= RandomForestRegressor(n_estimators = 100, random_state=42).fit(scaler,y)

print('RF/ Z_점수 정확도:%.2f'%(RandomF.score(scaler,y)*100),"%")
###########
scaler = robust_scale(X)

RandomF= RandomForestRegressor(n_estimators = 100, random_state=42).fit(scaler,y)

print('RF/ robust 정확도:%.2f'%(RandomF.score(scaler,y)*100),"%")
###########
scaler = minmax_scale(X)

RandomF= RandomForestRegressor(n_estimators = 100, random_state=42).fit(scaler,y)

print('RF/ minmax 정확도:%.2f'%(RandomF.score(scaler,y)*100),"%")
###########
scaler = maxabs_scale(X)

RandomF= RandomForestRegressor(n_estimators = 100, random_state=42).fit(scaler,y)

print('RF/ maxabs 정확도:%.2f'%(RandomF.score(scaler,y)*100),"%")
###########
# Out:
# RF/ Z_점수 정확도:80.27 %
# RF/ robust 정확도:80.25 %
# RF/ minmax 정확도:80.25 %
# RF/ maxabs 정확도:80.26 %

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import PolynomialFeatures

def PolynomialRegression(degree = 2, **kwargs):   # ** : dictionary 변동 매개변수 (여러개 들어오게)
    return make_pipeline(PolynomialFeatures(degree), LinearRegression(**kwargs))

# 0~20 중에서, intercept 있을지 말지, normalize 있을지 말지 최적을 찾아라   (__ : 불러오기)
param_grid = {'polynomialfeatures__degree' : np.arange(21),   # 21
              'linearregression__fit_intercept' :[True, False],  #2
             'linearregression__normalize': [True, False]}   # 2

# %%
grid = GridSearchCV (PolynomialRegression(), param_grid, cv = 7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-209-f876cf2bc8de> in <module>
# ----> 1 grid = GridSearchCV (PolynomialRegression(), param_grid, cv = 7)
#
# <ipython-input-208-8ae49a970006> in PolynomialRegression(degree, **kwargs)
#       4
#       5 def PolynomialRegression(degree = 2, **kwargs):   # ** : dictionary 변동 매개변수 (여러개 들어오게)
# ----> 6     return make_pipeline(PolynomialFeatures(degree), LinearRegression(**kwargs))
#       7
#       8 # 0~20 중에서, intercept 있을지 말지, normalize 있을지 말지 최적을 찾아라   (__ : 불러오기)
#
# NameError: name 'make_pipeline' is not defined

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(X)

SVC2 = SVC(degree=3,C=0.01).fit(scaled_data,y)

print('정확도:%.2f'%(SVC2.score(scaled_data,y)*100),"%")
# Out:
# 정확도:15.38 %
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(X)

randomF= RandomForestRegressor(n_estimators=100,max_depth =3,min_samples_leaf=1).fit(scaled_data,y)

print('정확도:%.2f'%(randomF.score(scaled_data,y)*100),"%")
# Out:
# 정확도:72.70 %

# %%
# 앙상블
from sklearn.ensemble import VotingRegressor,VotingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor

log_clf = LogisticRegression()
rnd_clf = RandomForestRegressor()
svm_clf = SVC()


voting_clf = VotingRegressor(estimators=[('lr', log_clf),('rf',rnd_clf),('svc',svm_clf)], n_jobs=-1)
#VotingRegressor()
voting_clf.fit(X,y)
# Out:
# VotingRegressor(estimators=[('lr',
#                              LogisticRegression(C=1.0, class_weight=None,
#                                                 dual=False, fit_intercept=True,
#                                                 intercept_scaling=1,
#                                                 l1_ratio=None, max_iter=100,
#                                                 multi_class='warn', n_jobs=None,
#                                                 penalty='l2', random_state=None,
#                                                 solver='warn', tol=0.0001,
#                                                 verbose=0, warm_start=False)),
#                             ('rf',
#                              RandomForestRegressor(bootstrap=True,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_fe...
# ...

# %%
voting_clf.score(X,y)
# Out:
# 0.9753698411259305

# %%
# Random forest 
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.preprocessing import scale, robust_scale, minmax_scale , maxabs_scale
scaler = scale(X)

RandomF= RandomForestRegressor(n_estimators = 100, random_state=42).fit(scaler,y)

print('RF/ Z_점수 정확도:%.2f'%(RandomF.score(scaler,y)*100),"%")
###########
scaler = robust_scale(X)

RandomF= RandomForestRegressor(n_estimators = 100, random_state=42).fit(scaler,y)

print('RF/ robust 정확도:%.2f'%(RandomF.score(scaler,y)*100),"%")
###########
scaler = minmax_scale(X)

RandomF= RandomForestRegressor(n_estimators = 100, random_state=42).fit(scaler,y)

print('RF/ minmax 정확도:%.2f'%(RandomF.score(scaler,y)*100),"%")
###########
scaler = maxabs_scale(X)

RandomF= RandomForestRegressor(n_estimators = 100, random_state=42).fit(scaler,y)

print('RF/ maxabs 정확도:%.2f'%(RandomF.score(scaler,y)*100),"%")
###########
# Out:
# RF/ Z_점수 정확도:80.27 %
# RF/ robust 정확도:80.25 %
# RF/ minmax 정확도:80.25 %
# RF/ maxabs 정확도:80.26 %

# %%
from sklearn.preprocessing import scale, robust_scale, minmax_scale , maxabs_scale
scaler = scale(X)

#scaled_data = scale.fit(x)

logreg= LogisticRegression(solver='lbfgs',max_iter=20).fit(scaler,y)

print("Logi.Regre Z점수 정확도:%.2f" %(logreg.score(scaler,y)*100),"%")
#
scaler = maxabs_scale(X)

#scaled_data = scale.fit(x)

logreg= LogisticRegression(solver='lbfgs',max_iter=20).fit(scaler,y)

print('Logi.Regre maxabs점수 정확도:%.2f'%(logreg.score(scaler,y)*100),"%")
#
scaler = minmax_scale(X)

#scaled_data = scale.fit(x)

logreg= LogisticRegression(solver='lbfgs',max_iter=20).fit(scaler,y)

print('Logi.Regre minmax점수 정확도:%.2f'%(logreg.score(scaler,y)*100),"%")
#
scaler = robust_scale(X)

#scaled_data = scale.fit(x)

logreg= LogisticRegression(solver='lbfgs',max_iter=20).fit(scaler,y)

print('Logi.Regre robust점수 정확도:%.2f'%(logreg.score(scaler,y)*100),"%")
# Out:
# Logi.Regre Z점수 정확도:100.00 %
# Logi.Regre maxabs점수 정확도:15.38 %
# Logi.Regre minmax점수 정확도:34.62 %
# Logi.Regre robust점수 정확도:96.15 %
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\ICT01_09\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
# gridsearchCV
from sklearn.pipeline import make_pipeline
from sklearn.naive_bayes import MultinomialNB   # Naive Bayes : 베이즈값으로 분류
from sklearn.preprocessing import Binarizer 
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC   # support vectore classifier
from sklearn.decomposition import PCA

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVC

pipe_svc = Pipeline([('scl', StandardScaler()), ('clf', SVC(random_state=1))])

param_range = [ 0.01, 0.1, 1.0, 10.0]
param_grid = [
    {'clf__C' : param_range, 'clf__kernel': ['linear']},
    {'clf__C': param_range, 'clf__gamma': param_range, 'clf__kernel':['rbf']}]

gs = GridSearchCV(estimator = pipe_svc, param_grid = param_grid,
                 scoring= 'accuracy', cv = 2, n_jobs=1)
# %time gs = gs.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-62443e7a053a> in <module>
#       5 from sklearn.svm import SVC
#       6
# ----> 7 pipe_svc = Pipeline([('scl', StandardScaler()), ('clf', SVC(random_state=1))])
#       8
#       9 param_range = [ 0.01, 0.1, 1.0, 10.0]
#
# NameError: name 'StandardScaler' is not defined

# %%
gs.cv_results_["params"]
# Out:
# [{'clf__C': 0.0001, 'clf__kernel': 'linear'},
#  {'clf__C': 0.001, 'clf__kernel': 'linear'},
#  {'clf__C': 0.01, 'clf__kernel': 'linear'},
#  {'clf__C': 0.1, 'clf__kernel': 'linear'},
#  {'clf__C': 1.0, 'clf__kernel': 'linear'},
#  {'clf__C': 10.0, 'clf__kernel': 'linear'},
#  {'clf__C': 100.0, 'clf__kernel': 'linear'},
#  {'clf__C': 1000.0, 'clf__kernel': 'linear'},
#  {'clf__C': 0.0001, 'clf__gamma': 0.0001, 'clf__kernel': 'rbf'},
#  {'clf__C': 0.0001, 'clf__gamma': 0.001, 'clf__kernel': 'rbf'},
#  {'clf__C': 0.0001, 'clf__gamma': 0.01, 'clf__kernel': 'rbf'},
#  {'clf__C': 0.0001, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'},
#  {'clf__C': 0.0001, 'clf__gamma': 1.0, 'clf__kernel': 'rbf'},
#  {'clf__C': 0.0001, 'clf__gamma': 10.0, 'clf__kernel': 'rbf'},
#  {'clf__C': 0.0001, 'clf__gamma': 100.0, 'clf__kernel': 'rbf'},
#  {'clf__C': 0.0001, 'clf__gamma': 1000.0, 'clf__kernel': 'rbf'},
#  {'clf__C': 0.001, 'clf__gamma': 0.0001, 'clf__kernel': 'rbf'},
# ...

# %%
gs.cv_results_["mean_test_score"]
# Out:
# array([0.11538462, 0.11538462, 0.11538462, 0.11538462, 0.11538462,
#        0.11538462, 0.11538462, 0.11538462, 0.11538462, 0.11538462,
#        0.11538462, 0.11538462, 0.11538462, 0.07692308, 0.07692308,
#        0.03846154, 0.11538462, 0.11538462, 0.11538462, 0.11538462,
#        0.11538462, 0.07692308, 0.07692308, 0.03846154, 0.11538462,
#        0.11538462, 0.11538462, 0.11538462, 0.11538462, 0.07692308,
#        0.07692308, 0.03846154, 0.11538462, 0.11538462, 0.11538462,
#        0.11538462, 0.11538462, 0.07692308, 0.07692308, 0.03846154,
#        0.11538462, 0.11538462, 0.11538462, 0.11538462, 0.11538462,
#        0.07692308, 0.07692308, 0.03846154, 0.11538462, 0.11538462,
#        0.11538462, 0.11538462, 0.11538462, 0.07692308, 0.07692308,
#        0.03846154, 0.11538462, 0.11538462, 0.11538462, 0.11538462,
#        0.11538462, 0.07692308, 0.07692308, 0.03846154, 0.11538462,
#        0.11538462, 0.11538462, 0.11538462, 0.11538462, 0.07692308,
#        0.07692308, 0.03846154])

# %%
print(gs.best_score_)
print(gs.best_params_)
# Out:
# 0.11538461538461539
# {'clf__C': 0.0001, 'clf__kernel': 'linear'}

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV    # parameter tuning
from sklearn.preprocessing import PolynomialFeatures  # 다차원 특성 축소

# 파이프라인 리턴
def PolynomialRegression(degree = 2, **kwargs):   # ** : dictionary 변동 매개변수 (여러개 들어오게)
    return make_pipeline(PolynomialFeatures(degree), LinearRegression(**kwargs))

# 0~20 중에서, intercept 있을지 말지, normalize 있을지 말지 최적을 찾아라   (__ : 불러오기)
param_grid = {'polynomialfeatures__degree' : np.arange(21),   # 21
              'linearregression__fit_intercept' :[True, False],  #2
             'linearregression__normalize': [True, False]}   # 2

grid = GridSearchCV(PolynomialRegression(), param_grid, cv = 2)  

grid.fit(X,y);
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-43165d88fcd2> in <module>
#      15 grid = GridSearchCV(PolynomialRegression(), param_grid, cv = 2)
#      16
# ---> 17 grid.fit(X,y);
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     686                 return results
#     687
# --> 688             self._run_search(evaluate_candidates)
#     689
#     690         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1147     def _run_search(self, evaluate_candidates):
#    1148         """Search all candidates in param_grid"""
# -> 1149         evaluate_candidates(ParameterGrid(self.param_grid))
#    1150
#    1151
#
# ...

# %%
grid.best_score_
